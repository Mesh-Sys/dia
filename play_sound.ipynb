# %% [markdown]
# <a href="https://colab.research.google.com/github/Mesh-Sys/dia/blob/main/play_sound.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/Mesh-Sys/dia.git

# %%
# %cd /content/dia
# Out:
# /content/dia

# %%
from IPython.display import Audio, display

# %%
#display(Audio("simple.mp3"))
#display(Audio("voice_clone_girl.mp3"))
display(Audio("voice_clone_merged_0.mp3"))
#display(Audio("voice_clone_merged_1.mp3"))
#display(Audio("voice_clone_merged_2.mp3"))
#display(Audio("voice_clone_merged_3.mp3"))
#display(Audio("voice_clone_merged_4.mp3"))
#display(Audio("voice_clone_merged_5.mp3"))
#display(Audio("voice_clone_merged.mp3"))
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
